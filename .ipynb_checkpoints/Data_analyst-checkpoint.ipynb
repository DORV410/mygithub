# %% [markdown]
# COlECTING DATA

# %%
import numpy as np
import numpy.random as rd

import matplotlib.pyplot as plt

# %%
x = rd.randint(100,size=10)
y = np.arange(1,11)
plt.plot(y,x)

# %%
x = rd.normal(n =10,size =3)
